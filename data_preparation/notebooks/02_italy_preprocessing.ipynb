# %% [markdown]
# <h1>Retired People and “Retired Places”: Italy, Data Preprocessing<span class="tocSkip"></span></h1>
# <div class="toc">
#   <ol class="toc-item">
#     <li>
#       <span>
#         <a href="#Loading-input-datasets" data-toc-modified-id="Loading-input-datasets-1">
#           <span class="toc-item-num"></span>Loading input datasets
#         </a>
#       </span>
#     </li>
#     <li>
#       <span>
#         <a href="#Processing-housing-data" data-toc-modified-id="Processing-housing-data-2">
#           <span class="toc-item-num"></span>Processing housing data
#         </a>
#       </span>
#     </li>
#     <li>
#       <span>
#         <a href="#Processing-population-data" data-toc-modified-id="Processing-population-data-3">
#           <span class="toc-item-num"></span>Processing population data
#         </a>
#       </span>
#     </li>
#     <li>
#       <span>
#         <a href="#Merging-into-final-dataset" data-toc-modified-id="Merging-into-final-dataset-4">
#           <span class="toc-item-num"></span>Merging into final dataset
#         </a>
#       </span>
#     </li>
#   </ol>
# </div>

# %% [markdown]
# ## Loading input datasets <a id="Loading-input-datasets"></a>

# %%
import pandas as pd
from pathlib import Path
import geopandas as gpd

print('Libraries are downloaded')
# Out:
# Libraries are downloaded

# %%
PROJECT_ROOT = Path("..").resolve().parent

PROCESSED = PROJECT_ROOT / "data" / "processed"

PROCESSED
# Out:
# PosixPath('/Users/eugenia/Desktop/Open Access/project/retired_places/data/processed')

# %%
df_population_it = pd.read_csv(PROCESSED / "pop_reg_it_clean.csv")
df_housing_it = pd.read_csv(PROCESSED / "homes_it_clean.csv")

gdf_places_all = gpd.read_file(PROCESSED / "MED1_settlements_italy.gpkg", layer="places")
gdf_regions = gpd.read_file(PROCESSED / "italy_regions.geojson")

# %%
df_housing_it.head()
# Out:
#                              region  homes_occupied  homes_unoccupied  \
# 0                        Piemonte           1964108            827768
# 1  Valle d'Aosta / Vallée d'Aoste             59616             75948
# 2                         Liguria            746686            431321
# 3                       Lombardia           4415364           1184728
# 4  Trentino Alto Adige / Südtirol            463305            219888
#
#    homes_total
# 0      2791876
# 1       135564
# 2      1178007
# 3      5600092
# 4       683193

# %%
df_population_it.head(110)
# Out:
#      region_code      region  age  pop_male  pop_female  pop_total
# 0             13     Abruzzo  0.0    3842.0      3577.0     7419.0
# 1             13     Abruzzo  1.0    4010.0      3653.0     7663.0
# 2             13     Abruzzo  2.0    4260.0      3873.0     8133.0
# 3             13     Abruzzo  3.0    4298.0      4163.0     8461.0
# 4             13     Abruzzo  4.0    4456.0      4163.0     8619.0
# ..           ...         ...  ...       ...         ...        ...
# 105           17  Basilicata  3.0    1755.0      1608.0     3363.0
# 106           17  Basilicata  4.0    1864.0      1674.0     3538.0
# 107           17  Basilicata  5.0    1929.0      1749.0     3678.0
# 108           17  Basilicata  6.0    1904.0      1819.0     3723.0
# 109           17  Basilicata  7.0    2098.0      1875.0     3973.0
#
# [110 rows x 6 columns]

# %%
gdf_places_all.head()
# Out:
#      osm_id  code   fclass  population        name                  geometry
# 0  59889482  1004   hamlet           0      Poggio   POINT (8.72158 46.0813)
# 1  59943000  1004   hamlet           0     Virasca  POINT (8.65932 45.94051)
# 2  60005756  1003  village           0    Folsogno  POINT (8.55015 46.13431)
# 3  60169984  1003  village           0  Sant'Agata  POINT (8.68572 46.07089)
# 4  62505581  1001     city     1350000      Milano  POINT (9.18963 45.46419)

# %%
gdf_regions.head()
# Out:
#    COD_RIP  COD_REG              DEN_REG    Shape_Leng    Shape_Area  \
# 0        1        1             Piemonte  1.204253e+06  2.538884e+10
# 1        1        2        Valle d'Aosta  3.068811e+05  3.260045e+09
# 2        1        3            Lombardia  1.380027e+06  2.386128e+10
# 3        2        4  Trentino-Alto Adige  7.818018e+05  1.360618e+10
# 4        2        5               Veneto  1.033420e+06  1.835382e+10
#
#                                             geometry
# 0  POLYGON ((8.44549 46.46371, 8.44654 46.46348, ...
# 1  POLYGON ((7.57478 45.98748, 7.57762 45.98646, ...
# 2  MULTIPOLYGON (((8.81427 45.01739, 8.81351 45.0...
# 3  POLYGON ((12.20868 47.08622, 12.21624 47.08546...
# 4  POLYGON ((12.51368 46.67811, 12.51964 46.67677...

# %% [markdown]
# ## Processing housing data <a id="Processing-housing-data"></a>

# %%
df_housing_it
# Out:
#                                   region  homes_occupied  homes_unoccupied  \
# 0                             Piemonte           1964108            827768
# 1       Valle d'Aosta / Vallée d'Aoste             59616             75948
# 2                              Liguria            746686            431321
# 3                            Lombardia           4415364           1184728
# 4       Trentino Alto Adige / Südtirol            463305            219888
# 5   Provincia Autonoma Bolzano / Bozen            226675             67100
# 6            Provincia Autonoma Trento            236630            152788
# 7                               Veneto           2076568            584378
# 8                Friuli-Venezia Giulia            557109            173363
# 9                       Emilia-Romagna           1993088            554077
# 10                             Toscana           1627013            506892
# 11                              Umbria            376747            126922
# 12                              Marche            635066            236436
# 13                               Lazio           2555710            618760
# 14                             Abruzzo            548556            346189
# 15                              Molise            128545            103339
# 16                            Campania           2163946            709914
# 17                              Puglia           1604719            699580
# 18                          Basilicata            232997            131810
# 19                            Calabria            794685            580819
# 20                             Sicilia           2024043           1157217
# 21                            Sardegna            722186            312423
#
#     homes_total
# 0       2791876
# 1        135564
# 2       1178007
# 3       5600092
# 4        683193
# 5        293775
# 6        389418
# 7       2660946
# 8        730472
# 9       2547165
# 10      2133905
# 11       503669
# 12       871502
# 13      3174470
# 14       894745
# 15       231884
# 16      2873860
# 17      2304299
# 18       364807
# 19      1375504
# 20      3181260
# 21      1034609

# %%
# normalize region names 
def normalize_region_name(s: str) -> str:
    s = s.strip()
    s = s.replace(" / ", "/")          
    s = s.replace(" - ", "-")        
    s = s.replace("–", "-")            
    return s

df_housing_it["region_norm"] = (
    df_housing_it["region"]
    .astype(str)
    .apply(normalize_region_name)
)

df_housing_it
# Out:
#                                   region  homes_occupied  homes_unoccupied  \
# 0                             Piemonte           1964108            827768
# 1       Valle d'Aosta / Vallée d'Aoste             59616             75948
# 2                              Liguria            746686            431321
# 3                            Lombardia           4415364           1184728
# 4       Trentino Alto Adige / Südtirol            463305            219888
# 5   Provincia Autonoma Bolzano / Bozen            226675             67100
# 6            Provincia Autonoma Trento            236630            152788
# 7                               Veneto           2076568            584378
# 8                Friuli-Venezia Giulia            557109            173363
# 9                       Emilia-Romagna           1993088            554077
# 10                             Toscana           1627013            506892
# 11                              Umbria            376747            126922
# 12                              Marche            635066            236436
# 13                               Lazio           2555710            618760
# 14                             Abruzzo            548556            346189
# 15                              Molise            128545            103339
# 16                            Campania           2163946            709914
# 17                              Puglia           1604719            699580
# 18                          Basilicata            232997            131810
# 19                            Calabria            794685            580819
# 20                             Sicilia           2024043           1157217
# 21                            Sardegna            722186            312423
#
#     homes_total                       region_norm
# 0       2791876                          Piemonte
# 1        135564      Valle d'Aosta/Vallée d'Aoste
# 2       1178007                           Liguria
# 3       5600092                         Lombardia
# 4        683193      Trentino Alto Adige/Südtirol
# 5        293775  Provincia Autonoma Bolzano/Bozen
# 6        389418         Provincia Autonoma Trento
# 7       2660946                            Veneto
# 8        730472             Friuli-Venezia Giulia
# 9       2547165                    Emilia-Romagna
# 10      2133905                           Toscana
# 11       503669                            Umbria
# 12       871502                            Marche
# 13      3174470                             Lazio
# 14       894745                           Abruzzo
# 15       231884                            Molise
# 16      2873860                          Campania
# 17      2304299                            Puglia
# 18       364807                        Basilicata
# 19      1375504                          Calabria
# 20      3181260                           Sicilia
# 21      1034609                          Sardegna

# %%
# create dict with region codes for datasets mashing 
region_codes = {
    "Piemonte": 1,
    "Valle d'Aosta/Vallée d'Aoste": 2,
    "Lombardia": 3,
    "Trentino-Alto Adige/Südtirol": 4,
    "Veneto": 5,
    "Friuli-Venezia Giulia": 6,
    "Liguria": 7,
    "Emilia-Romagna": 8,
    "Toscana": 9,
    "Umbria": 10,
    "Marche": 11,
    "Lazio": 12,
    "Abruzzo": 13,
    "Molise": 14,
    "Campania": 15,
    "Puglia": 16,
    "Basilicata": 17,
    "Calabria": 18,
    "Sicilia": 19,
    "Sardegna": 20,
}

# region code maping
df_housing_it["region_code"] = df_housing_it["region_norm"].map(region_codes)

# %%
# check
print(df_housing_it[df_housing_it["region_code"].isna()][["region", "region_norm"]].head())
# Out:
#                                  region                       region_norm
# 4      Trentino Alto Adige / Südtirol        Trentino Alto Adige/Südtirol
# 5  Provincia Autonoma Bolzano / Bozen    Provincia Autonoma Bolzano/Bozen
# 6           Provincia Autonoma Trento           Provincia Autonoma Trento

# %% [markdown]
# The data providers chose to disaggregate Trentino-Alto Adige/Südtirol into three separate units (the whole region plus the two autonomous provinces, Bolzano/Bozen and Trento). As a result, these entries did not initially have a corresponding ISTAT region code in our region_codes dictionary and had to be added manually.

# %%
region_codes.update({
    "Trentino Alto Adige/Südtirol": 4,
    "Provincia Autonoma Bolzano/Bozen": 4,
    "Provincia Autonoma Trento": 4,
})

df_housing_it["region_code"] = df_housing_it["region_norm"].map(region_codes)

# %%
df_housing_it
# Out:
#                                   region  homes_occupied  homes_unoccupied  \
# 0                             Piemonte           1964108            827768
# 1       Valle d'Aosta / Vallée d'Aoste             59616             75948
# 2                              Liguria            746686            431321
# 3                            Lombardia           4415364           1184728
# 4       Trentino Alto Adige / Südtirol            463305            219888
# 5   Provincia Autonoma Bolzano / Bozen            226675             67100
# 6            Provincia Autonoma Trento            236630            152788
# 7                               Veneto           2076568            584378
# 8                Friuli-Venezia Giulia            557109            173363
# 9                       Emilia-Romagna           1993088            554077
# 10                             Toscana           1627013            506892
# 11                              Umbria            376747            126922
# 12                              Marche            635066            236436
# 13                               Lazio           2555710            618760
# 14                             Abruzzo            548556            346189
# 15                              Molise            128545            103339
# 16                            Campania           2163946            709914
# 17                              Puglia           1604719            699580
# 18                          Basilicata            232997            131810
# 19                            Calabria            794685            580819
# 20                             Sicilia           2024043           1157217
# 21                            Sardegna            722186            312423
#
#     homes_total                       region_norm  region_code
# 0       2791876                          Piemonte            1
# 1        135564      Valle d'Aosta/Vallée d'Aoste            2
# 2       1178007                           Liguria            7
# 3       5600092                         Lombardia            3
# 4        683193      Trentino Alto Adige/Südtirol            4
# 5        293775  Provincia Autonoma Bolzano/Bozen            4
# 6        389418         Provincia Autonoma Trento            4
# 7       2660946                            Veneto            5
# 8        730472             Friuli-Venezia Giulia            6
# 9       2547165                    Emilia-Romagna            8
# 10      2133905                           Toscana            9
# 11       503669                            Umbria           10
# 12       871502                            Marche           11
# 13      3174470                             Lazio           12
# 14       894745                           Abruzzo           13
# 15       231884                            Molise           14
# 16      2873860                          Campania           15
# 17      2304299                            Puglia           16
# 18       364807                        Basilicata           17
# 19      1375504                          Calabria           18
# 20      3181260                           Sicilia           19
# 21      1034609                          Sardegna           20

# %% [markdown]
# We dropped the rows for Provincia Autonoma Bolzano/Bozen and Provincia Autonoma Trento because their values sum exactly to the regional total for Trentino-Alto Adige/Südtirol, and keeping all three would double-count the same housing units in our regional-level analysis.

# %%
mask = df_housing_it["region_norm"].str.contains("Provincia Autonoma", na=False)

df_housing_it = df_housing_it[~mask].reset_index(drop=True)


df_housing_it
# Out:
#                               region  homes_occupied  homes_unoccupied  \
# 0                         Piemonte           1964108            827768
# 1   Valle d'Aosta / Vallée d'Aoste             59616             75948
# 2                          Liguria            746686            431321
# 3                        Lombardia           4415364           1184728
# 4   Trentino Alto Adige / Südtirol            463305            219888
# 5                           Veneto           2076568            584378
# 6            Friuli-Venezia Giulia            557109            173363
# 7                   Emilia-Romagna           1993088            554077
# 8                          Toscana           1627013            506892
# 9                           Umbria            376747            126922
# 10                          Marche            635066            236436
# 11                           Lazio           2555710            618760
# 12                         Abruzzo            548556            346189
# 13                          Molise            128545            103339
# 14                        Campania           2163946            709914
# 15                          Puglia           1604719            699580
# 16                      Basilicata            232997            131810
# 17                        Calabria            794685            580819
# 18                         Sicilia           2024043           1157217
# 19                        Sardegna            722186            312423
#
#     homes_total                   region_norm  region_code
# 0       2791876                      Piemonte            1
# 1        135564  Valle d'Aosta/Vallée d'Aoste            2
# 2       1178007                       Liguria            7
# 3       5600092                     Lombardia            3
# 4        683193  Trentino Alto Adige/Südtirol            4
# 5       2660946                        Veneto            5
# 6        730472         Friuli-Venezia Giulia            6
# 7       2547165                Emilia-Romagna            8
# 8       2133905                       Toscana            9
# 9        503669                        Umbria           10
# 10       871502                        Marche           11
# 11      3174470                         Lazio           12
# 12       894745                       Abruzzo           13
# 13       231884                        Molise           14
# 14      2873860                      Campania           15
# 15      2304299                        Puglia           16
# 16       364807                    Basilicata           17
# 17      1375504                      Calabria           18
# 18      3181260                       Sicilia           19
# 19      1034609                      Sardegna           20

# %%
# count unoccupied homes share
df_housing_it["share_unoccupied"] = (
    df_housing_it["homes_unoccupied"] / df_housing_it["homes_total"] * 100
)

df_housing_it
# Out:
#                               region  homes_occupied  homes_unoccupied  \
# 0                         Piemonte           1964108            827768
# 1   Valle d'Aosta / Vallée d'Aoste             59616             75948
# 2                          Liguria            746686            431321
# 3                        Lombardia           4415364           1184728
# 4   Trentino Alto Adige / Südtirol            463305            219888
# 5                           Veneto           2076568            584378
# 6            Friuli-Venezia Giulia            557109            173363
# 7                   Emilia-Romagna           1993088            554077
# 8                          Toscana           1627013            506892
# 9                           Umbria            376747            126922
# 10                          Marche            635066            236436
# 11                           Lazio           2555710            618760
# 12                         Abruzzo            548556            346189
# 13                          Molise            128545            103339
# 14                        Campania           2163946            709914
# 15                          Puglia           1604719            699580
# 16                      Basilicata            232997            131810
# 17                        Calabria            794685            580819
# 18                         Sicilia           2024043           1157217
# 19                        Sardegna            722186            312423
#
#     homes_total                   region_norm  region_code  share_unoccupied
# 0       2791876                      Piemonte            1         29.649168
# 1        135564  Valle d'Aosta/Vallée d'Aoste            2         56.023723
# 2       1178007                       Liguria            7         36.614468
# 3       5600092                     Lombardia            3         21.155510
# 4        683193  Trentino Alto Adige/Südtirol            4         32.185341
# 5       2660946                        Veneto            5         21.961287
# 6        730472         Friuli-Venezia Giulia            6         23.733011
# 7       2547165                Emilia-Romagna            8         21.752694
# 8       2133905                       Toscana            9         23.754197
# 9        503669                        Umbria           10         25.199486
# 10       871502                        Marche           11         27.129714
# 11      3174470                         Lazio           12         19.491758
# 12       894745                       Abruzzo           13         38.691359
# 13       231884                        Molise           14         44.564955
# 14      2873860                      Campania           15         24.702456
# 15      2304299                        Puglia           16         30.359775
# 16       364807                    Basilicata           17         36.131434
# 17      1375504                      Calabria           18         42.225904
# 18      3181260                       Sicilia           19         36.376059
# 19      1034609                      Sardegna           20         30.197205

# %%
it_free_homes = PROCESSED / "MD1_share_houses_occupation.csv"
df_housing_it.to_csv(it_free_homes, index=False)

print(f"saved to: {it_free_homes}")
# Out:
# saved to: /Users/eugenia/Desktop/Open Access/project/retired_places/data/processed/MD1_share_houses_occupation.csv

# %% [markdown]
# ## Processing population data <a id="Processing-population-data"></a>

# %%
# extract total regions population
it_total_age = df_population_it[df_population_it["age"] == 999]
it_total_age
# Out:
#       region_code                        region    age   pop_male  pop_female  \
# 101            13                       Abruzzo  999.0   622936.0    645494.0
# 203            17                    Basilicata  999.0   262604.0    267293.0
# 305            18                      Calabria  999.0   899712.0    932435.0
# 407            15                      Campania  999.0  2726809.0   2848216.0
# 509             8                Emilia-Romagna  999.0  2194241.0   2271437.0
# 611             6         Friuli-Venezia Giulia  999.0   584758.0    609337.0
# 713            12                         Lazio  999.0  2771470.0   2938802.0
# 815             7                       Liguria  999.0   731614.0    778294.0
# 917             3                     Lombardia  999.0  4946391.0   5089090.0
# 1019           11                        Marche  999.0   726773.0    754479.0
# 1121           14                        Molise  999.0   143062.0    144904.0
# 1223            1                      Piemonte  999.0  2083188.0   2172514.0
# 1325           16                        Puglia  999.0  1892105.0   1982061.0
# 1427           20                      Sardegna  999.0   767700.0    793639.0
# 1529           19                       Sicilia  999.0  2333921.0   2445450.0
# 1631            9                       Toscana  999.0  1784130.0   1876704.0
# 1733            4  Trentino-Alto Adige/Südtirol  999.0   538389.0    547706.0
# 1835           10                        Umbria  999.0   413891.0    438063.0
# 1937            2  Valle d'Aosta/Vallée d'Aoste  999.0    60285.0     62429.0
# 2039            5                        Veneto  999.0  2392820.0   2459031.0
#
#        pop_total
# 101    1268430.0
# 203     529897.0
# 305    1832147.0
# 407    5575025.0
# 509    4465678.0
# 611    1194095.0
# 713    5710272.0
# 815    1509908.0
# 917   10035481.0
# 1019   1481252.0
# 1121    287966.0
# 1223   4255702.0
# 1325   3874166.0
# 1427   1561339.0
# 1529   4779371.0
# 1631   3660834.0
# 1733   1086095.0
# 1835    851954.0
# 1937    122714.0
# 2039   4851851.0

# %%
# add total region population as a separate column
totals_for_merge = (
    it_total_age[["region_code", "pop_total"]]
    .rename(columns={"pop_total": "pop_total_all_ages"})
)

df_population_it = df_population_it.merge(
    totals_for_merge,
    on="region_code",
    how="left"
)

df_population_it
# Out:
#       region_code   region    age   pop_male  pop_female  pop_total  \
# 0              13  Abruzzo    0.0     3842.0      3577.0     7419.0
# 1              13  Abruzzo    1.0     4010.0      3653.0     7663.0
# 2              13  Abruzzo    2.0     4260.0      3873.0     8133.0
# 3              13  Abruzzo    3.0     4298.0      4163.0     8461.0
# 4              13  Abruzzo    4.0     4456.0      4163.0     8619.0
# ...           ...      ...    ...        ...         ...        ...
# 2035            5   Veneto   97.0      601.0      2244.0     2845.0
# 2036            5   Veneto   98.0      350.0      1524.0     1874.0
# 2037            5   Veneto   99.0      221.0      1023.0     1244.0
# 2038            5   Veneto  100.0      267.0      1654.0     1921.0
# 2039            5   Veneto  999.0  2392820.0   2459031.0  4851851.0
#
#       pop_total_all_ages
# 0              1268430.0
# 1              1268430.0
# 2              1268430.0
# 3              1268430.0
# 4              1268430.0
# ...                  ...
# 2035           4851851.0
# 2036           4851851.0
# 2037           4851851.0
# 2038           4851851.0
# 2039           4851851.0
#
# [2040 rows x 7 columns]

# %%
# count share of retired people
df_population_it = df_population_it[df_population_it["age"] != 999].copy()

df_population_it["pop_65plus_tmp"] = df_population_it["pop_total"].where(
    df_population_it["age"] >= 65,
    0
)

df_population_it.head(70)
# Out:
#     region_code   region   age  pop_male  pop_female  pop_total  \
# 0            13  Abruzzo   0.0    3842.0      3577.0     7419.0
# 1            13  Abruzzo   1.0    4010.0      3653.0     7663.0
# 2            13  Abruzzo   2.0    4260.0      3873.0     8133.0
# 3            13  Abruzzo   3.0    4298.0      4163.0     8461.0
# 4            13  Abruzzo   4.0    4456.0      4163.0     8619.0
# ..          ...      ...   ...       ...         ...        ...
# 65           13  Abruzzo  65.0    8625.0      9412.0    18037.0
# 66           13  Abruzzo  66.0    8259.0      9010.0    17269.0
# 67           13  Abruzzo  67.0    8105.0      8812.0    16917.0
# 68           13  Abruzzo  68.0    8100.0      8573.0    16673.0
# 69           13  Abruzzo  69.0    7832.0      8722.0    16554.0
#
#     pop_total_all_ages  pop_65plus_tmp
# 0            1268430.0             0.0
# 1            1268430.0             0.0
# 2            1268430.0             0.0
# 3            1268430.0             0.0
# 4            1268430.0             0.0
# ..                 ...             ...
# 65           1268430.0         18037.0
# 66           1268430.0         17269.0
# 67           1268430.0         16917.0
# 68           1268430.0         16673.0
# 69           1268430.0         16554.0
#
# [70 rows x 8 columns]

# %%
# count people after 65 in every region 
df_region_65_it = (
    df_population_it
    .groupby(["region_code", "region"], as_index=False)
    .agg(
        pop_65plus=("pop_65plus_tmp", "sum"),        
        tot_pop=("pop_total_all_ages", "first"),    
    )
)

df_region_65_it.head()
# Out:
#    region_code                        region  pop_65plus     tot_pop
# 0            1                      Piemonte   1142793.0   4255702.0
# 1            2  Valle d'Aosta/Vallée d'Aoste     31686.0    122714.0
# 2            3                     Lombardia   2394067.0  10035481.0
# 3            4  Trentino-Alto Adige/Südtirol    244707.0   1086095.0
# 4            5                        Veneto   1208173.0   4851851.0

# %%
# count share of 65 +
df_region_65_it["share_65plus"] = df_region_65_it["pop_65plus"] / df_region_65_it["tot_pop"] * 100

# %%
df_region_65_it.head(20)
# Out:
#     region_code                        region  pop_65plus     tot_pop  \
# 0             1                      Piemonte   1142793.0   4255702.0
# 1             2  Valle d'Aosta/Vallée d'Aoste     31686.0    122714.0
# 2             3                     Lombardia   2394067.0  10035481.0
# 3             4  Trentino-Alto Adige/Südtirol    244707.0   1086095.0
# 4             5                        Veneto   1208173.0   4851851.0
# 5             6         Friuli-Venezia Giulia    328115.0   1194095.0
# 6             7                       Liguria    440645.0   1509908.0
# 7             8                Emilia-Romagna   1112536.0   4465678.0
# 8             9                       Toscana    977876.0   3660834.0
# 9            10                        Umbria    232730.0    851954.0
# 10           11                        Marche    393278.0   1481252.0
# 11           12                         Lazio   1360591.0   5710272.0
# 12           13                       Abruzzo    330163.0   1268430.0
# 13           14                        Molise     78139.0    287966.0
# 14           15                      Campania   1194002.0   5575025.0
# 15           16                        Puglia    958479.0   3874166.0
# 16           17                    Basilicata    137402.0    529897.0
# 17           18                      Calabria    447739.0   1832147.0
# 18           19                       Sicilia   1131710.0   4779371.0
# 19           20                      Sardegna    428342.0   1561339.0
#
#     share_65plus
# 0      26.853220
# 1      25.821015
# 2      23.856026
# 3      22.530902
# 4      24.901280
# 5      27.478132
# 6      29.183566
# 7      24.913037
# 8      26.711837
# 9      27.317203
# 10     26.550378
# 11     23.827079
# 12     26.029265
# 13     27.134801
# 14     21.416980
# 15     24.740267
# 16     25.929945
# 17     24.437941
# 18     23.679057
# 19     27.434273

# %%
it_65_path = PROCESSED / "MD2_share_65_plus.csv"
df_region_65_it.to_csv(it_65_path, index=False)

print(f"saved to: {it_65_path}")
# Out:
# saved to: /Users/eugenia/Desktop/Open Access/project/retired_places/data/processed/MD2_share_65_plus.csv

# %% [markdown]
# ## Processing geo data <a id="Processing-geo-data"></a>

# %% [markdown]
# We would like to count the Dispersed Settlements Index. For this from the dataset with places we retain only features tagged as place=village and place=hamlet, which correspond to small settlements below 10,000 inhabitants. We explicitly exclude larger centres (city, town), intra-urban units (suburb), non-settlement features (island, farm, region, county, locality). This keeps the index focused on the fine-grained rural and semi-rural settlement pattern rather than on the higher-order urban hierarchy.

# %%
# filtering by class: village and hamlet
gdf_small_places = (
    gdf_places_all[gdf_places_all["fclass"].isin(["village", "hamlet"])]
    .loc[:, ["fclass", "name", "geometry"]]
    .copy()
)

# check
print("All places:", len(gdf_places_all))
print("Only village + hamlet:", len(gdf_small_places))
print(gdf_small_places["fclass"].value_counts())
# Out:
# All places: 141922
# Only village + hamlet: 62849
# fclass
# hamlet     48131
# village    14718
# Name: count, dtype: int64

# %%
gdf_small_places.head()
# Out:
#      fclass        name                  geometry
# 0    hamlet      Poggio   POINT (8.72158 46.0813)
# 1    hamlet     Virasca  POINT (8.65932 45.94051)
# 2   village    Folsogno  POINT (8.55015 46.13431)
# 3   village  Sant'Agata  POINT (8.68572 46.07089)
# 13  village    Bedulita  POINT (9.55155 45.79165)

# %%
gdf_regions.columns
# Out:
# Index(['COD_RIP', 'COD_REG', 'DEN_REG', 'Shape_Leng', 'Shape_Area',
#        'geometry'],
#       dtype='object')

# %%
# taking features we need
gdf_regions_min = gdf_regions[["COD_REG", "DEN_REG", "geometry"]].copy()

# sjoin for each give region code and name 
gdf_places_with_region = gpd.sjoin(
    gdf_small_places,
    gdf_regions_min,
    how="left",       
    predicate="within" 
)

# check
gdf_places_with_region.tail()
# Out:
#         fclass                  name                   geometry  index_right  \
# 141838  hamlet             Su Tillio    POINT (9.78144 40.5474)         19.0
# 141839  hamlet           Santa Lcuia   POINT (8.61482 39.98251)         19.0
# 141881  hamlet  San Leonardo Sottano  POINT (15.09094 37.35183)         18.0
# 141885  hamlet               Cicogne   POINT (14.57531 37.0186)         18.0
# 141895  hamlet              Borgo 84  POINT (15.11854 36.72397)         18.0
#
#         COD_REG   DEN_REG
# 141838     20.0  Sardegna
# 141839     20.0  Sardegna
# 141881     19.0   Sicilia
# 141885     19.0   Sicilia
# 141895     19.0   Sicilia

# %%
# check if there is any place without clear region code
missing_region = gdf_places_with_region[gdf_places_with_region["COD_REG"].isna()]
print("Settlements without a region:", len(missing_region))
# Out:
# Settlements without a region: 179

# %% [markdown]
# A small number of settlement points (179) could not be matched to any regional polygon (likely due to minor boundary and coastline mismatches). Since our analysis is conducted at the regional level, we dropped these unmatched points and computed all indicators only for settlements that fall within an official regional boundary.

# %%
gdf_places_with_region = (
    gdf_places_with_region
    .dropna(subset=["COD_REG"])
    .copy()
)

# unifying column names
gdf_places_with_region = gdf_places_with_region.rename(
    columns={
        "COD_REG": "region_code",
        "DEN_REG": "region",
    }
)

# changing type
gdf_places_with_region["region_code"] = gdf_places_with_region["region_code"].astype(int)

# index_right column
gdf_places_with_region = gdf_places_with_region.drop(columns=["index_right"])

# check
gdf_places_with_region.head()
# Out:
#      fclass        name                  geometry  region_code     region
# 0    hamlet      Poggio   POINT (8.72158 46.0813)            3  Lombardia
# 1    hamlet     Virasca  POINT (8.65932 45.94051)            3  Lombardia
# 2   village    Folsogno  POINT (8.55015 46.13431)            1   Piemonte
# 3   village  Sant'Agata  POINT (8.68572 46.07089)            1   Piemonte
# 13  village    Bedulita  POINT (9.55155 45.79165)            3  Lombardia

# %%
# count how many small settlements fall into each region
df_settlements_region = (
    gdf_places_with_region
    .groupby(["region_code", "region"], as_index=False)
    .size()                               
    .rename(columns={"size": "settlements_count"})
)

df_settlements_region.head()
# Out:
#    region_code               region  settlements_count
# 0            1             Piemonte               9220
# 1            2        Valle d'Aosta               2901
# 2            3            Lombardia               8531
# 3            4  Trentino-Alto Adige               2625
# 4            5               Veneto               5888

# %%
# saving settlement df
settlements_path = PROCESSED / "MD3_settlements_count.csv"
df_settlements_region.to_csv(settlements_path, index=False)

print(f"saved to: {settlements_path}")
# Out:
# saved to: /Users/eugenia/Desktop/Open Access/project/retired_places/data/processed/MD3_settlements_count.csv

# %% [markdown]
# ## Merging into final dataset <a id="Merging-into-final-dataset"></a>

# %% [markdown]
# Firstly, we merge regional population table with the settlements counts.

# %%
#    left join to keep all regions from df_region_65_it,
#    even if for some reason a region has zero villages/hamlets 
df_italy_dispersion = df_region_65_it.merge(
    df_settlements_region[["region_code", "settlements_count"]],
    on="region_code",
    how="left"
)

# replace missing settlements_count with 0
df_italy_dispersion["settlements_count"] = (
    df_italy_dispersion["settlements_count"]
    .fillna(0)
    .astype(int)
)

# compute the Dispersed Settlements Index: number of settlements per 1,000 inhabitants
df_italy_dispersion["dispersed_index"] = (
    df_italy_dispersion["settlements_count"]
    / (df_italy_dispersion["tot_pop"] / 1000)
)

# 4. select relevant columns
df_italy_dispersion = df_italy_dispersion[
    [
        "region_code",
        "region",
        "tot_pop",
        "settlements_count",
        "dispersed_index",
        "share_65plus"
    ]
]

# check
df_italy_dispersion.head()
# Out:
#    region_code                        region     tot_pop  settlements_count  \
# 0            1                      Piemonte   4255702.0               9220
# 1            2  Valle d'Aosta/Vallée d'Aoste    122714.0               2901
# 2            3                     Lombardia  10035481.0               8531
# 3            4  Trentino-Alto Adige/Südtirol   1086095.0               2625
# 4            5                        Veneto   4851851.0               5888
#
#    dispersed_index  share_65plus
# 0         2.166505     26.853220
# 1        23.640334     25.821015
# 2         0.850084     23.856026
# 3         2.416916     22.530902
# 4         1.213557     24.901280

# %% [markdown]
# We want to add share of unoccupied houses and macroregions to the dataframe.

# %%
df_housing_subset = df_housing_it[["region_code", "share_unoccupied"]].copy()

df_italy_dispersion = df_italy_dispersion.merge(
    df_housing_subset,
    on="region_code",
    how="left"   
)

df_italy_dispersion.head()
# Out:
#    region_code                        region     tot_pop  settlements_count  \
# 0            1                      Piemonte   4255702.0               9220
# 1            2  Valle d'Aosta/Vallée d'Aoste    122714.0               2901
# 2            3                     Lombardia  10035481.0               8531
# 3            4  Trentino-Alto Adige/Südtirol   1086095.0               2625
# 4            5                        Veneto   4851851.0               5888
#
#    dispersed_index  share_65plus  share_unoccupied
# 0         2.166505     26.853220         29.649168
# 1        23.640334     25.821015         56.023723
# 2         0.850084     23.856026         21.155510
# 3         2.416916     22.530902         32.185341
# 4         1.213557     24.901280         21.961287

# %%
macro_map = {
    "Piemonte": "North",
    "Valle d'Aosta/Vallée d'Aoste": "North",
    "Lombardia": "North",
    "Trentino-Alto Adige/Südtirol": "North",
    "Veneto": "North",
    "Friuli-Venezia Giulia": "North",
    "Liguria": "North",
    "Emilia-Romagna": "North",
    "Toscana": "Centre",
    "Umbria": "Centre",
    "Marche": "Centre",
    "Lazio": "Centre",
    "Abruzzo": "South",
    "Molise": "South",
    "Campania": "South",
    "Puglia": "South",
    "Basilicata": "South",
    "Calabria": "South",
    "Sicilia": "Islands",
    "Sardegna": "Islands",
}

df_italy_dispersion["macro_region"] = df_italy_dispersion["region"].map(macro_map)

df_italy_dispersion
# Out:
#     region_code                        region     tot_pop  settlements_count  \
# 0             1                      Piemonte   4255702.0               9220
# 1             2  Valle d'Aosta/Vallée d'Aoste    122714.0               2901
# 2             3                     Lombardia  10035481.0               8531
# 3             4  Trentino-Alto Adige/Südtirol   1086095.0               2625
# 4             5                        Veneto   4851851.0               5888
# 5             6         Friuli-Venezia Giulia   1194095.0               1966
# 6             7                       Liguria   1509908.0               2196
# 7             8                Emilia-Romagna   4465678.0               8052
# 8             9                       Toscana   3660834.0               5316
# 9            10                        Umbria    851954.0               1901
# 10           11                        Marche   1481252.0               2722
# 11           12                         Lazio   5710272.0               1660
# 12           13                       Abruzzo   1268430.0               2220
# 13           14                        Molise    287966.0                454
# 14           15                      Campania   5575025.0               1871
# 15           16                        Puglia   3874166.0                471
# 16           17                    Basilicata    529897.0                349
# 17           18                      Calabria   1832147.0               1414
# 18           19                       Sicilia   4779371.0               1738
# 19           20                      Sardegna   1561339.0               1175
#
#     dispersed_index  share_65plus  share_unoccupied macro_region
# 0          2.166505     26.853220         29.649168        North
# 1         23.640334     25.821015         56.023723        North
# 2          0.850084     23.856026         21.155510        North
# 3          2.416916     22.530902         32.185341        North
# 4          1.213557     24.901280         21.961287        North
# 5          1.646435     27.478132         23.733011        North
# 6          1.454393     29.183566         36.614468        North
# 7          1.803086     24.913037         21.752694        North
# 8          1.452128     26.711837         23.754197       Centre
# 9          2.231341     27.317203         25.199486       Centre
# 10         1.837635     26.550378         27.129714       Centre
# 11         0.290704     23.827079         19.491758       Centre
# 12         1.750195     26.029265         38.691359        South
# 13         1.576575     27.134801         44.564955        South
# 14         0.335604     21.416980         24.702456        South
# 15         0.121575     24.740267         30.359775        South
# 16         0.658619     25.929945         36.131434        South
# 17         0.771772     24.437941         42.225904        South
# 18         0.363646     23.679057         36.376059      Islands
# 19         0.752559     27.434273         30.197205      Islands

# %%
# saving dicpersion index df
disp_path = PROCESSED / "MD4_dispertion_places.csv"
df_italy_dispersion.to_csv(disp_path, index=False)

print(f"saved to: {disp_path}")
# Out:
# saved to: /Users/eugenia/Desktop/Open Access/project/retired_places/data/processed/MD4_dispertion_places.csv

# %% [markdown]
# Creating df with population and housing data.

# %%
df_italy_merged = df_region_65_it.merge(
    df_housing_it,
    on="region_code",
    how="left"
)

df_italy_merged = df_italy_merged.drop(columns=["region_y"])
df_italy_merged = df_italy_merged.rename(columns={"region_x": "region"})

df_italy_merged
# Out:
#     region_code                        region  pop_65plus     tot_pop  \
# 0             1                      Piemonte   1142793.0   4255702.0
# 1             2  Valle d'Aosta/Vallée d'Aoste     31686.0    122714.0
# 2             3                     Lombardia   2394067.0  10035481.0
# 3             4  Trentino-Alto Adige/Südtirol    244707.0   1086095.0
# 4             5                        Veneto   1208173.0   4851851.0
# 5             6         Friuli-Venezia Giulia    328115.0   1194095.0
# 6             7                       Liguria    440645.0   1509908.0
# 7             8                Emilia-Romagna   1112536.0   4465678.0
# 8             9                       Toscana    977876.0   3660834.0
# 9            10                        Umbria    232730.0    851954.0
# 10           11                        Marche    393278.0   1481252.0
# 11           12                         Lazio   1360591.0   5710272.0
# 12           13                       Abruzzo    330163.0   1268430.0
# 13           14                        Molise     78139.0    287966.0
# 14           15                      Campania   1194002.0   5575025.0
# 15           16                        Puglia    958479.0   3874166.0
# 16           17                    Basilicata    137402.0    529897.0
# 17           18                      Calabria    447739.0   1832147.0
# 18           19                       Sicilia   1131710.0   4779371.0
# 19           20                      Sardegna    428342.0   1561339.0
#
#     share_65plus  homes_occupied  homes_unoccupied  homes_total  \
# 0      26.853220         1964108            827768      2791876
# 1      25.821015           59616             75948       135564
# 2      23.856026         4415364           1184728      5600092
# 3      22.530902          463305            219888       683193
# 4      24.901280         2076568            584378      2660946
# 5      27.478132          557109            173363       730472
# 6      29.183566          746686            431321      1178007
# 7      24.913037         1993088            554077      2547165
# 8      26.711837         1627013            506892      2133905
# 9      27.317203          376747            126922       503669
# 10     26.550378          635066            236436       871502
# 11     23.827079         2555710            618760      3174470
# 12     26.029265          548556            346189       894745
# 13     27.134801          128545            103339       231884
# 14     21.416980         2163946            709914      2873860
# 15     24.740267         1604719            699580      2304299
# 16     25.929945          232997            131810       364807
# 17     24.437941          794685            580819      1375504
# 18     23.679057         2024043           1157217      3181260
# 19     27.434273          722186            312423      1034609
#
#                      region_norm  share_unoccupied
# 0                       Piemonte         29.649168
# 1   Valle d'Aosta/Vallée d'Aoste         56.023723
# 2                      Lombardia         21.155510
# 3   Trentino Alto Adige/Südtirol         32.185341
# 4                         Veneto         21.961287
# 5          Friuli-Venezia Giulia         23.733011
# 6                        Liguria         36.614468
# 7                 Emilia-Romagna         21.752694
# 8                        Toscana         23.754197
# 9                         Umbria         25.199486
# 10                        Marche         27.129714
# 11                         Lazio         19.491758
# 12                       Abruzzo         38.691359
# 13                        Molise         44.564955
# 14                      Campania         24.702456
# 15                        Puglia         30.359775
# 16                    Basilicata         36.131434
# 17                      Calabria         42.225904
# 18                       Sicilia         36.376059
# 19                      Sardegna         30.197205

# %%
# adding macro region
df_italy_merged["macro_region"] = df_italy_merged["region"].map(macro_map)

df_italy_merged
# Out:
#     region_code                        region  pop_65plus     tot_pop  \
# 0             1                      Piemonte   1142793.0   4255702.0
# 1             2  Valle d'Aosta/Vallée d'Aoste     31686.0    122714.0
# 2             3                     Lombardia   2394067.0  10035481.0
# 3             4  Trentino-Alto Adige/Südtirol    244707.0   1086095.0
# 4             5                        Veneto   1208173.0   4851851.0
# 5             6         Friuli-Venezia Giulia    328115.0   1194095.0
# 6             7                       Liguria    440645.0   1509908.0
# 7             8                Emilia-Romagna   1112536.0   4465678.0
# 8             9                       Toscana    977876.0   3660834.0
# 9            10                        Umbria    232730.0    851954.0
# 10           11                        Marche    393278.0   1481252.0
# 11           12                         Lazio   1360591.0   5710272.0
# 12           13                       Abruzzo    330163.0   1268430.0
# 13           14                        Molise     78139.0    287966.0
# 14           15                      Campania   1194002.0   5575025.0
# 15           16                        Puglia    958479.0   3874166.0
# 16           17                    Basilicata    137402.0    529897.0
# 17           18                      Calabria    447739.0   1832147.0
# 18           19                       Sicilia   1131710.0   4779371.0
# 19           20                      Sardegna    428342.0   1561339.0
#
#     share_65plus  homes_occupied  homes_unoccupied  homes_total  \
# 0      26.853220         1964108            827768      2791876
# 1      25.821015           59616             75948       135564
# 2      23.856026         4415364           1184728      5600092
# 3      22.530902          463305            219888       683193
# 4      24.901280         2076568            584378      2660946
# 5      27.478132          557109            173363       730472
# 6      29.183566          746686            431321      1178007
# 7      24.913037         1993088            554077      2547165
# 8      26.711837         1627013            506892      2133905
# 9      27.317203          376747            126922       503669
# 10     26.550378          635066            236436       871502
# 11     23.827079         2555710            618760      3174470
# 12     26.029265          548556            346189       894745
# 13     27.134801          128545            103339       231884
# 14     21.416980         2163946            709914      2873860
# 15     24.740267         1604719            699580      2304299
# 16     25.929945          232997            131810       364807
# 17     24.437941          794685            580819      1375504
# 18     23.679057         2024043           1157217      3181260
# 19     27.434273          722186            312423      1034609
#
#                      region_norm  share_unoccupied macro_region
# 0                       Piemonte         29.649168        North
# 1   Valle d'Aosta/Vallée d'Aoste         56.023723        North
# 2                      Lombardia         21.155510        North
# 3   Trentino Alto Adige/Südtirol         32.185341        North
# 4                         Veneto         21.961287        North
# 5          Friuli-Venezia Giulia         23.733011        North
# 6                        Liguria         36.614468        North
# 7                 Emilia-Romagna         21.752694        North
# 8                        Toscana         23.754197       Centre
# 9                         Umbria         25.199486       Centre
# 10                        Marche         27.129714       Centre
# 11                         Lazio         19.491758       Centre
# 12                       Abruzzo         38.691359        South
# 13                        Molise         44.564955        South
# 14                      Campania         24.702456        South
# 15                        Puglia         30.359775        South
# 16                    Basilicata         36.131434        South
# 17                      Calabria         42.225904        South
# 18                       Sicilia         36.376059      Islands
# 19                      Sardegna         30.197205      Islands

# %% [markdown]
# To move from two continuous indicators to an interpretable typology, we defined binary flags for “high” ageing and “high” vacancy using simple, data-driven thresholds (the median values of share_65plus and share_unoccupied). We then combined these flags into a four-fold categorical variable, category_2x2, which assigns each region to one of four types: “Old & Empty” (high ageing, high vacancy), “Old & Lived-in” (high ageing, low vacancy), “Younger but Emptying” (low ageing, high vacancy), and “Younger & Lived-in” (low ageing, low vacancy). This discrete typology makes it easier to communicate and compare how different regions position themselves along the joint dimensions of demographic ageing and housing under-use.

# %%
# Use the median values as simple, data-driven thresholds
# for defining "high" ageing and "high" vacancy.
thr_65 = df_italy_merged["share_65plus"].median()          # threshold for high share of 65+ residents
thr_vac = df_italy_merged["share_unoccupied"].median()     # threshold for high share of unoccupied homes

# Create binary flags: is this region above or below each threshold?
df_italy_merged["high_65"] = df_italy_merged["share_65plus"] >= thr_65
df_italy_merged["high_vac"] = df_italy_merged["share_unoccupied"] >= thr_vac

# Map each combination of (high_65, high_vac) into a human-readable 2×2 category.
def cat(row):
    # High ageing and high vacancy: both people and places are "retired"
    if row["high_65"] and row["high_vac"]:
        return "Old & Empty"
    # High ageing but low vacancy: many older people, but housing is still actively used
    if row["high_65"] and not row["high_vac"]:
        return "Old & Lived-in"
    # Low ageing but high vacancy: relatively younger population, but many empty homes
    if not row["high_65"] and row["high_vac"]:
        return "Younger but Emptying"
    # Low ageing and low vacancy: younger population and intensively used housing stock
    return "Younger & Lived-in"

# Apply the function row by row to assign each region to one of the four types.
df_italy_merged["category_2x2"] = df_italy_merged.apply(cat, axis=1)

df_italy_merged
# Out:
#     region_code                        region  pop_65plus     tot_pop  \
# 0             1                      Piemonte   1142793.0   4255702.0
# 1             2  Valle d'Aosta/Vallée d'Aoste     31686.0    122714.0
# 2             3                     Lombardia   2394067.0  10035481.0
# 3             4  Trentino-Alto Adige/Südtirol    244707.0   1086095.0
# 4             5                        Veneto   1208173.0   4851851.0
# 5             6         Friuli-Venezia Giulia    328115.0   1194095.0
# 6             7                       Liguria    440645.0   1509908.0
# 7             8                Emilia-Romagna   1112536.0   4465678.0
# 8             9                       Toscana    977876.0   3660834.0
# 9            10                        Umbria    232730.0    851954.0
# 10           11                        Marche    393278.0   1481252.0
# 11           12                         Lazio   1360591.0   5710272.0
# 12           13                       Abruzzo    330163.0   1268430.0
# 13           14                        Molise     78139.0    287966.0
# 14           15                      Campania   1194002.0   5575025.0
# 15           16                        Puglia    958479.0   3874166.0
# 16           17                    Basilicata    137402.0    529897.0
# 17           18                      Calabria    447739.0   1832147.0
# 18           19                       Sicilia   1131710.0   4779371.0
# 19           20                      Sardegna    428342.0   1561339.0
#
#     share_65plus  homes_occupied  homes_unoccupied  homes_total  \
# 0      26.853220         1964108            827768      2791876
# 1      25.821015           59616             75948       135564
# 2      23.856026         4415364           1184728      5600092
# 3      22.530902          463305            219888       683193
# 4      24.901280         2076568            584378      2660946
# 5      27.478132          557109            173363       730472
# 6      29.183566          746686            431321      1178007
# 7      24.913037         1993088            554077      2547165
# 8      26.711837         1627013            506892      2133905
# 9      27.317203          376747            126922       503669
# 10     26.550378          635066            236436       871502
# 11     23.827079         2555710            618760      3174470
# 12     26.029265          548556            346189       894745
# 13     27.134801          128545            103339       231884
# 14     21.416980         2163946            709914      2873860
# 15     24.740267         1604719            699580      2304299
# 16     25.929945          232997            131810       364807
# 17     24.437941          794685            580819      1375504
# 18     23.679057         2024043           1157217      3181260
# 19     27.434273          722186            312423      1034609
#
#                      region_norm  share_unoccupied macro_region  high_65  \
# 0                       Piemonte         29.649168        North     True
# 1   Valle d'Aosta/Vallée d'Aoste         56.023723        North    False
# 2                      Lombardia         21.155510        North    False
# 3   Trentino Alto Adige/Südtirol         32.185341        North    False
# 4                         Veneto         21.961287        North    False
# 5          Friuli-Venezia Giulia         23.733011        North     True
# 6                        Liguria         36.614468        North     True
# 7                 Emilia-Romagna         21.752694        North    False
# 8                        Toscana         23.754197       Centre     True
# 9                         Umbria         25.199486       Centre     True
# 10                        Marche         27.129714       Centre     True
# 11                         Lazio         19.491758       Centre    False
# 12                       Abruzzo         38.691359        South     True
# 13                        Molise         44.564955        South     True
# 14                      Campania         24.702456        South    False
# 15                        Puglia         30.359775        South    False
# 16                    Basilicata         36.131434        South     True
# 17                      Calabria         42.225904        South    False
# 18                       Sicilia         36.376059      Islands    False
# 19                      Sardegna         30.197205      Islands     True
#
#     high_vac          category_2x2
# 0      False        Old & Lived-in
# 1       True  Younger but Emptying
# 2      False    Younger & Lived-in
# 3       True  Younger but Emptying
# 4      False    Younger & Lived-in
# 5      False        Old & Lived-in
# 6       True           Old & Empty
# 7      False    Younger & Lived-in
# 8      False        Old & Lived-in
# 9      False        Old & Lived-in
# 10     False        Old & Lived-in
# 11     False    Younger & Lived-in
# 12      True           Old & Empty
# 13      True           Old & Empty
# 14     False    Younger & Lived-in
# 15      True  Younger but Emptying
# 16      True           Old & Empty
# 17      True  Younger but Emptying
# 18      True  Younger but Emptying
# 19      True           Old & Empty

# %% [markdown]
# To compare regions on a relative scale, we computed separate rank positions for ageing and vacancy. First, we ranked regions by the share of residents aged 65+ (rank_65), and then by the share of unoccupied homes (rank_vac), with higher ranks indicating higher values of the corresponding indicator. We then calculated a simple divergence measure, rank_diff = rank_vac – rank_65. Positive values of rank_diff identify regions where vacancy is higher than one would expect given their ageing rank (i.e. “emptier than their level of ageing”), while negative values indicate regions that are relatively older than one would expect given their vacancy rank (i.e. “more aged than their level of housing under-use”).

# %%
# Compute rank positions for ageing and vacancy to compare regions on a relative scale.
# A higher rank means a higher value of the indicator (more ageing / more vacancy).

# Rank of each region by share of 65+ residents
df_italy_merged["rank_65"] = df_italy_merged["share_65plus"].rank(method="average")

# Rank of each region by share of unoccupied homes
df_italy_merged["rank_vac"] = df_italy_merged["share_unoccupied"].rank(method="average")

# Difference in ranks: positive values mean the region is "emptier" than expected
# given its ageing rank; negative values mean it is "older" than expected
# given its vacancy rank.
df_italy_merged["rank_diff"] = df_italy_merged["rank_vac"] - df_italy_merged["rank_65"]

df_italy_merged
# Out:
#     region_code                        region  pop_65plus     tot_pop  \
# 0             1                      Piemonte   1142793.0   4255702.0
# 1             2  Valle d'Aosta/Vallée d'Aoste     31686.0    122714.0
# 2             3                     Lombardia   2394067.0  10035481.0
# 3             4  Trentino-Alto Adige/Südtirol    244707.0   1086095.0
# 4             5                        Veneto   1208173.0   4851851.0
# 5             6         Friuli-Venezia Giulia    328115.0   1194095.0
# 6             7                       Liguria    440645.0   1509908.0
# 7             8                Emilia-Romagna   1112536.0   4465678.0
# 8             9                       Toscana    977876.0   3660834.0
# 9            10                        Umbria    232730.0    851954.0
# 10           11                        Marche    393278.0   1481252.0
# 11           12                         Lazio   1360591.0   5710272.0
# 12           13                       Abruzzo    330163.0   1268430.0
# 13           14                        Molise     78139.0    287966.0
# 14           15                      Campania   1194002.0   5575025.0
# 15           16                        Puglia    958479.0   3874166.0
# 16           17                    Basilicata    137402.0    529897.0
# 17           18                      Calabria    447739.0   1832147.0
# 18           19                       Sicilia   1131710.0   4779371.0
# 19           20                      Sardegna    428342.0   1561339.0
#
#     share_65plus  homes_occupied  homes_unoccupied  homes_total  \
# 0      26.853220         1964108            827768      2791876
# 1      25.821015           59616             75948       135564
# 2      23.856026         4415364           1184728      5600092
# 3      22.530902          463305            219888       683193
# 4      24.901280         2076568            584378      2660946
# 5      27.478132          557109            173363       730472
# 6      29.183566          746686            431321      1178007
# 7      24.913037         1993088            554077      2547165
# 8      26.711837         1627013            506892      2133905
# 9      27.317203          376747            126922       503669
# 10     26.550378          635066            236436       871502
# 11     23.827079         2555710            618760      3174470
# 12     26.029265          548556            346189       894745
# 13     27.134801          128545            103339       231884
# 14     21.416980         2163946            709914      2873860
# 15     24.740267         1604719            699580      2304299
# 16     25.929945          232997            131810       364807
# 17     24.437941          794685            580819      1375504
# 18     23.679057         2024043           1157217      3181260
# 19     27.434273          722186            312423      1034609
#
#                      region_norm  share_unoccupied macro_region  high_65  \
# 0                       Piemonte         29.649168        North     True
# 1   Valle d'Aosta/Vallée d'Aoste         56.023723        North    False
# 2                      Lombardia         21.155510        North    False
# 3   Trentino Alto Adige/Südtirol         32.185341        North    False
# 4                         Veneto         21.961287        North    False
# 5          Friuli-Venezia Giulia         23.733011        North     True
# 6                        Liguria         36.614468        North     True
# 7                 Emilia-Romagna         21.752694        North    False
# 8                        Toscana         23.754197       Centre     True
# 9                         Umbria         25.199486       Centre     True
# 10                        Marche         27.129714       Centre     True
# 11                         Lazio         19.491758       Centre    False
# 12                       Abruzzo         38.691359        South     True
# 13                        Molise         44.564955        South     True
# 14                      Campania         24.702456        South    False
# 15                        Puglia         30.359775        South    False
# 16                    Basilicata         36.131434        South     True
# 17                      Calabria         42.225904        South    False
# 18                       Sicilia         36.376059      Islands    False
# 19                      Sardegna         30.197205      Islands     True
#
#     high_vac          category_2x2  rank_65  rank_vac  rank_diff
# 0      False        Old & Lived-in     15.0      10.0       -5.0
# 1       True  Younger but Emptying     10.0      20.0       10.0
# 2      False    Younger & Lived-in      5.0       2.0       -3.0
# 3       True  Younger but Emptying      2.0      13.0       11.0
# 4      False    Younger & Lived-in      8.0       4.0       -4.0
# 5      False        Old & Lived-in     19.0       5.0      -14.0
# 6       True           Old & Empty     20.0      16.0       -4.0
# 7      False    Younger & Lived-in      9.0       3.0       -6.0
# 8      False        Old & Lived-in     14.0       6.0       -8.0
# 9      False        Old & Lived-in     17.0       8.0       -9.0
# 10     False        Old & Lived-in     13.0       9.0       -4.0
# 11     False    Younger & Lived-in      4.0       1.0       -3.0
# 12      True           Old & Empty     12.0      17.0        5.0
# 13      True           Old & Empty     16.0      19.0        3.0
# 14     False    Younger & Lived-in      1.0       7.0        6.0
# 15      True  Younger but Emptying      7.0      12.0        5.0
# 16      True           Old & Empty     11.0      14.0        3.0
# 17      True  Younger but Emptying      6.0      18.0       12.0
# 18      True  Younger but Emptying      3.0      15.0       12.0
# 19      True           Old & Empty     18.0      11.0       -7.0

# %%
# saving final mashed df
it_homes_pop_path = PROCESSED / "MD5_age_houses_occupation.csv"
df_italy_merged.to_csv(it_homes_pop_path, index=False)

print(f"saved to: {it_homes_pop_path}")
# Out:
# saved to: /Users/eugenia/Desktop/Open Access/project/retired_places/data/processed/MD5_age_houses_occupation.csv
